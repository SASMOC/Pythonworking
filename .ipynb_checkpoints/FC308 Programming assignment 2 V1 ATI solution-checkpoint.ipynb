# %%
import random

def choose_word():
    words = ['apple', 'banana', 'cherry', 'date', 'elderberry', 'fig', 'grape']
    return random.choice(words)

def display_word(word, guessed_letters):
    output = ''
    for letter in word:
        if letter in guessed_letters:
            output += letter
        else:
            output += '-'
    return output

def play_game():
    word = choose_word()
    guessed_letters = set()
    max_incorrect_guesses = 6
    incorrect_guesses = 0
    
    while incorrect_guesses < max_incorrect_guesses:
        print('Secret word:', display_word(word, guessed_letters))
        print('Incorrect guesses left:', max_incorrect_guesses - incorrect_guesses)
        guess = input('Guess a letter: ').lower()
        if guess in guessed_letters:
            print('You already guessed that letter.')
        elif guess in word:
            guessed_letters.add(guess)
            if set(word) == guessed_letters:
                print('You won! The secret word was:', word)
                return
        else:
            incorrect_guesses += 1
            print('Incorrect guess.')
    
    print('You lost! The secret word was:', word)

while True:
    play_game()
    play_again = input('Do you want to play again? (y/n) ').lower()
    if play_again != 'y':
        break

# %% [markdown]
# # Algorithm
# ### Import necessary libraries
# ### Define a list of words to choose from randomly
# ### Choose a word randomly from the list and save it in a variable
# ### Create a variable to store the maximum number of incorrect guesses allowed
# ### Create a variable to store the current number of incorrect guesses made
# ### Create a list to store the letters guessed by the user
# ### Create a list to store the correctly guessed letters and their positions in the word
# ###  Create a function to display the current state of the game (i.e., the word with dashes and the letters guessed so far)
# ###  Create a function to get a guess from the user
# ### Create a function to check if the guess is in the word and update the guessed letters list and the correctly guessed letters list if it is
# ### Update the number of incorrect guesses made if the guess is not in the word
# ### Check if the user has won or lost the game (i.e., all letters have been guessed correctly or the maximum number of incorrect guesses has been reached)
# ### Ask the user if they want to play again
# ### If the user wants to play again, repeat from step 3
# ### Key variables, functions, and data structures:
#
# ### words: a list of words to choose from randomly
# ### secret_word: the randomly chosen word from the list
# ### max_incorrect_guesses: the maximum number of incorrect guesses allowed
# ### incorrect_guesses_made: the current number of incorrect guesses made
# ### guessed_letters: a list of letters guessed by the user
# ### correct_letters: a list of correctly guessed letters and their positions in the word
# ### display_game_state(): a function to display the current state of the game
# ### get_guess(): a function to get a guess from the user
# ### update_guess(): a function to check if the guess is in the word and update the guessed letters list and the correctly guessed letters list if it is
# ### play_again(): a function to ask the user if they want to play again
# ### list: a data structure to store the letters guessed and correctly guessed letters and their positions in the word
# # Testing:
# ### To test the program, I would input various letters and test if the program correctly updates the guessed letters and the number of incorrect guesses made. I would also test if the program correctly identifies when the user has won or lost the game. I would also test if the program correctly asks the user if they want to play again and restarts the game if the user chooses to.
#
# # Summary:
# ### The program plays a game of Hangman with the user by randomly choosing a word from a list of words and displaying dashes for each letter of the word. The user guesses letters, one at a time, to try to guess the secret word. If the user guesses a letter in the secret word, that letter replaces the dash in the correct position. If the user guesses a letter that does not appear in the secret word, the program reduces the number of incorrect guesses available by one. If the user correctly guesses all the letters in the word, the user wins the game. Otherwise, when the user runs out of incorrect guesses, the program wins. After each game, the user has the option to play again.

# %%
import random

# Generate a random balance between £100 - £1000
balance = random.randint(100, 1000)

# Ask for the user's PIN code
for i in range(3):
    pin = input("Please enter your 4 digit PIN code: ")
    if pin == "1234":  # Replace "1234" with the correct PIN code
        print("PIN code accepted.")
        break
    else:
        print("Incorrect PIN code. Please try again.")
else:
    print("You have entered an incorrect PIN code 3 times. Your card has been retained.")
    exit()  # End the program if the user enters an incorrect PIN code 3 times

# Display the menu of options to the user
while True:
    print("\nMenu:")
    print("1. Check balance")
    print("2. Withdraw money")
    print("3. Deposit money")
    print("4. Quit")

    choice = input("Please enter your choice (1-4): ")

    if choice == "1":
        print("Your balance is £" + str(balance))

    elif choice == "2":
        amount = int(input("Please enter the amount to withdraw: "))
        if amount <= balance:
            balance -= amount
            print("Withdrawal successful. Your balance is now £" + str(balance))
        else:
            print("Insufficient funds.")

    elif choice == "3":
        amount = int(input("Please enter the amount to deposit: "))
        balance += amount
        print("Deposit successful. Your balance is now £" + str(balance))

    elif choice == "4":
        print("Thank you for using our ATM. Goodbye!")
        break

    else:
        print("Invalid choice. Please try again.")

# %% [markdown]
# # Algorithm:
#
# ### Import necessary libraries
# ### Define a variable to store the user's PIN
# ### Define a variable to store the maximum number of attempts to enter the PIN
# ### Define a variable to store the user's current balance (a randomly generated amount between £100 - £1000)
# ### Define a function to check if the entered PIN is correct
# ### If the PIN is incorrect, ask the user to enter their PIN again (up to the maximum number of attempts)
# ### If the PIN is correct, display a menu of options for the user to choose from (check balance, withdraw money, deposit money)
# ### If the user chooses to check their balance, display their current balance
# ### If the user chooses to withdraw money, ask them for the amount to withdraw and update their balance accordingly
# ### If the user chooses to deposit money, ask them for the amount to deposit and update their balance accordingly
# ### Ask the user if they want to perform another transaction
# ### If the user wants to perform another transaction, repeat from step 7
# ### If the user does not want to perform another transaction, end the program
# ### Key variables, functions, and data structures:
#
# ### pin: a variable to store the user's PIN
# ### max_attempts: a variable to store the maximum number of attempts to enter the PIN
# ### balance: a variable to store the user's current balance
# ### check_pin(): a function to check if the entered PIN is correct
# ### display_menu(): a function to display a menu of options for the user to choose from
# ### check_balance(): a function to display the user's current balance
# ### withdraw_money(): a function to ask the user for the amount to withdraw and update their balance accordingly
# ### deposit_money(): a function to ask the user for the amount to deposit and update their balance accordingly
# # Testing:
# ### To test the program, I would enter various PIN codes, both correct and incorrect, and test if the program correctly allows or denies access to the account. I would also test if the program correctly updates the balance when the user withdraws or deposits money. I would also test if the program correctly asks the user if they want to perform another transaction and restarts or ends the program accordingly.
#
# # Summary:
# ### The program simulates an ATM banking machine by asking the user for their 4 digit PIN code and allowing them to perform various transactions such as checking their balance, withdrawing money, and depositing money. The user's balance at the beginning of the transaction is a randomly generated amount between £100 - £1000. If the PIN is entered incorrectly 3 times, the program outputs a message to the effect that the card has been retained and restarts. After each transaction, the user has the option to perform another transaction or end the program.

# %%
Algorithm:

Import necessary libraries
Define a variable to store the user's PIN
Define a variable to store the user's balance, generated randomly between £100 - £1000
Create a variable to store the maximum number of attempts allowed to enter the correct PIN
Create a variable to store the current number of attempts made to enter the correct PIN
Ask the user to enter their PIN
Check if the entered PIN matches the stored PIN
If the PIN is correct, display a menu of options for the user to choose from (check balance, withdraw money, deposit money)
If the PIN is incorrect, increment the number of attempts made to enter the correct PIN
If the maximum number of attempts has been reached, output a message that the card has been retained and restart the program
If the maximum number of attempts has not been reached, repeat from step 6
If the user chooses to check their balance, display their current balance
If the user chooses to withdraw money, ask for the amount to withdraw and check if it is less than or equal to their balance. If it is, deduct the amount from their balance and display their new balance. If it is not, display an error message.
If the user chooses to deposit money, ask for the amount to deposit and add it to their balance. Display their new balance.
Ask the user if they want to perform another transaction
If the user wants to perform another transaction, repeat from step 8
Key variables, functions, and data structures:

pin: a variable to store the user's PIN
balance: a variable to store the user's balance, generated randomly between £100 - £1000
max_attempts: the maximum number of attempts allowed to enter the correct PIN
attempts_made: the current number of attempts made to enter the correct PIN
check_balance(): a function to display the user's current balance
withdraw_money(amount): a function to deduct the amount from the user's balance if it is less than or equal to their balance, and display their new balance
deposit_money(amount): a function to add the amount to the user's balance and display their new balance
int, float: data types for storing the user's PIN, balance, and transaction amounts
Testing:
To test the program, I would input various PIN codes and check if the program correctly allows access with the correct PIN and denies access after the maximum number of attempts has been reached with an incorrect PIN. I would also test if the program correctly displays the user's balance, allows the user to withdraw money up to their balance, and allows the user to deposit money and updates their balance correctly.

Summary:
The program simulates an ATM banking machine by asking the user for their PIN code and generating a random balance between £100 - £1000. The user has 3 attempts to enter their PIN correctly. If the PIN is entered incorrectly 3 times, the program outputs a message that the card has been retained and restarts. If the PIN is entered correctly, the user can check their balance, withdraw money up to the total of their balance, or deposit money into their account. After each transaction, the user can choose to perform another transaction.
